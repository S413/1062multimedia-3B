# %%
from skimage import io

img = io.imread('C:/Users/S_H/Pictures/master.jpg', as_grey=True)

print(type(img))
print(img.shape)

io.imshow(img)
io.show()

print("Yes Yes Yes Yes...YES")
# Out:
# <class 'numpy.ndarray'>
# (304, 540)
# Yes Yes Yes Yes...YES

# %%
# Out:
# no...
